# %% [markdown]
# ## <font color=7E4456>EAS 503 - Python</font>
# ### <font color=155E64>Final Project - Global Terrorism Data</font>
# ### GROUP MEMBERS:-
# #### Khushboo Lodaya,    Tanish Shah,      Ankit Kumar,          Vachan Patil

# %%
# pip install folium

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# Import required modules
import csv
import sqlite3


# Connecting to the database
connection = sqlite3.connect('global_terrorism.db')

# Creating a cursor object to execute
# SQL queries on a database table
cursor = connection.cursor()

# Table Definition
create_table = '''CREATE TABLE IF NOT EXISTS Global_Terrorism(
                        eventid TEXT,
                        iyear TEXT,
                        imonth TEXT,
                        iday TEXT,
                        approxdate TEXT,
                        extended TEXT,
                        resolution TEXT,
                        country TEXT,
                        country_txt TEXT,
                        region TEXT,
                        region_txt TEXT,
                        provstate TEXT,
                        city TEXT,
                        latitude TEXT,
                        longitude TEXT,
                        specificity TEXT,
                        vicinity TEXT,
                        location TEXT,
                        summary TEXT,
                        crit1 TEXT,
                        crit2 TEXT,
                        crit3 TEXT,
                        doubtterr TEXT,
                        alternative TEXT,
                        alternative_txt TEXT,
                        multiple TEXT,
                        success TEXT,
                        suicide TEXT,
                        attacktype1 TEXT,
                        attacktype1_txt TEXT,
                        attacktype2 INT,
                        attacktype2_txt TEXT,
                        attacktype3 INT,
                        attacktype3_txt TEXT,
                        targtype1 TEXT,
                        targtype1_txt TEXT,
                        targsubtype1 TEXT,
                        targsubtype1_txt TEXT,
                        corp1 TEXT,
                        target1 TEXT,
                        natlty1 TEXT,
                        natlty1_txt TEXT,
                        targtype2 TEXT,
                        targtype2_txt TEXT,
                        targsubtype2 TEXT,
                        targsubtype2_txt TEXT,
                        corp2 TEXT,
                        target2 TEXT,
                        natlty2 TEXT,
                        natlty2_txt TEXT,
                        targtype3 TEXT,
                        targtype3_txt TEXT,
                        targsubtype3 TEXT,
                        targsubtype3_txt TEXT,
                        corp3 TEXT,
                        target3 TEXT,
                        natlty3 TEXT,
                        natlty3_txt TEXT,
                        gname TEXT,
                        gsubname TEXT,
                        gname2 TEXT,
                        gsubname2 TEXT,
                        gname3 TEXT,
                        gsubname3 TEXT,
                        motive TEXT,
                        guncertain1 TEXT,
                        guncertain2 TEXT,
                        guncertain3 TEXT,
                        individual TEXT,
                        nperps TEXT,
                        nperpcap TEXT,
                        claimed TEXT,
                        claimmode TEXT,
                        claimmode_txt TEXT,
                        claim2 TEXT,
                        claimmode2 TEXT,
                        claimmode2_txt TEXT,
                        claim3 TEXT,
                        claimmode3 TEXT,
                        claimmode3_txt TEXT,
                        compclaim TEXT,
                        weaptype1 TEXT,
                        weaptype1_txt TEXT,
                        weapsubtype1 TEXT,
                        weapsubtype1_txt TEXT,
                        weaptype2 TEXT,
                        weaptype2_txt TEXT,
                        weapsubtype2 TEXT,
                        weapsubtype2_txt TEXT,
                        weaptype3 TEXT,
                        weaptype3_txt TEXT,
                        weapsubtype3 TEXT,
                        weapsubtype3_txt TEXT,
                        weaptype4 TEXT,
                        weaptype4_txt TEXT,
                        weapsubtype4 TEXT,
                        weapsubtype4_txt TEXT,
                        weapdetail TEXT,
                        nkill TEXT,
                        nkillus TEXT,
                        nkillter TEXT,
                        nwound TEXT,
                        nwoundus TEXT,
                        nwoundte TEXT,
                        property TEXT,
                        propextent TEXT,
                        propextent_txt TEXT,
                        propvalue TEXT,
                        propcomment TEXT,
                        ishostkid TEXT,
                        nhostkid TEXT,
                        nhostkidus TEXT,
                        nhours TEXT,
                        ndays TEXT,
                        divert TEXT,
                        kidhijcountry TEXT,
                        ransom TEXT,
                        ransomamt TEXT,
                        ransomamtus TEXT,
                        ransompaid TEXT,
                        ransompaidus TEXT,
                        ransomnote TEXT,
                        hostkidoutcome TEXT,
                        hostkidoutcome_txt TEXT,
                        nreleased TEXT,
                        addnotes TEXT,
                        scite1 TEXT,
                        scite2 TEXT,
                        scite3 TEXT,
                        dbsource TEXT,
                        INT_LOG TEXT,
                        INT_IDEO TEXT,
                        INT_MISC TEXT,
                        INT_ANY TEXT,
                        related TEXT
                );
'''

# Creating the table into our
# database
cursor.execute(create_table)

# Opening the globalterrorism.csv file
file = open('globalterrorism.csv')

# Reading the contents of the
# globalterrorism.csv file
contents = csv.reader(file)


# SQL query to insert data into the
# Global_Terrorism table
insert_records = "INSERT INTO Global_Terrorism VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)"
# Importing the contents of the file
# into our Global_Terrorism table
cursor.executemany(insert_records, contents)

# Committing the changes
connection.commit()

# closing the database connection
connection.close()

# %%
connection = sqlite3.connect('global_terrorism.db')
cursor = connection.cursor()
# SQL query to retrieve all data 
sql_statement = "SELECT * FROM Global_Terrorism"


df = pd.read_sql_query(sql_statement, connection)
#print(df)
    
connection.close()

# %%
display(df.head(5))
# Out:
#         eventid  iyear  imonth  iday  approxdate  extended  resolution  \
# 0       eventid  iyear  imonth  iday  approxdate  extended  resolution
# 1  197000000001   1970       7     2                     0
# 2  197000000002   1970       0     0                     0
# 3  197001000001   1970       1     0                     0
# 4  197001000002   1970       1     0                     0
#
#    country         country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# 0  country         country_txt  region  ...  addnotes  scite1  scite2  scite3
# 1       58  Dominican Republic       2  ...
# 2      130              Mexico       1  ...
# 3      160         Philippines       5  ...
# 4       78              Greece       8  ...
#
#    dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# 0  dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# 1      PGIS        0         0         0        0
# 2      PGIS        0         1         1        1
# ...

# %%
# dropping the 1st row, by selecting all rows from first row onwards
df = df.iloc[1: , :]

# restting the index after deleting the 1st row.
df = df.reset_index(drop=True)
df.head()
# Out:
#         eventid iyear imonth iday approxdate extended resolution country  \
# 0  197000000001  1970      7    2                   0                 58
# 1  197000000002  1970      0    0                   0                130
# 2  197001000001  1970      1    0                   0                160
# 3  197001000002  1970      1    0                   0                 78
# 4  197001000003  1970      1    0                   0                101
#
#           country_txt region  ... addnotes scite1 scite2 scite3 dbsource  \
# 0  Dominican Republic      2  ...                                   PGIS
# 1              Mexico      1  ...                                   PGIS
# 2         Philippines      5  ...                                   PGIS
# 3              Greece      8  ...                                   PGIS
# 4               Japan      4  ...                                   PGIS
#
#   INT_LOG INT_IDEO INT_MISC INT_ANY related
# 0       0        0        0       0
# ...

# %%
# Renaming the columns and using only those columns that are useful for visualisation
df.rename(columns={'eventid':'EventId','iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State',
                   'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                   'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                   'weaptype1_txt':'Weapon_type','motive':'Motive','city':'City', 'natlty1_txt':'Nationality',
                   'success':'Success'},inplace=True)

df=df[['EventId','Year','Month','Day','Country','State','Region','City','latitude','longitude','AttackType',
             'Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive','Nationality','Success']]


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214666 entries, 0 to 214665
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   EventId      214666 non-null  object
#  1   Year         214666 non-null  object
#  2   Month        214666 non-null  object
#  3   Day          214666 non-null  object
#  4   Country      214666 non-null  object
#  5   State        214666 non-null  object
#  6   Region       214666 non-null  object
#  7   City         214666 non-null  object
#  8   latitude     214666 non-null  object
#  9   longitude    214666 non-null  object
#  10  AttackType   214666 non-null  object
#  11  Killed       214666 non-null  object
#  12  Wounded      214666 non-null  object
#  13  Target       214666 non-null  object
#  14  Summary      214666 non-null  object
#  15  Group        214666 non-null  object
#  16  Target_type  214666 non-null  object
#  17  Weapon_type  214666 non-null  object
# ...

# %%
cols = ["EventId","Year","Month","Day","Success"]
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce', axis=1)

cols1 = ["latitude","longitude","Killed","Wounded"]
df[cols1] = df[cols1].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214666 entries, 0 to 214665
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   EventId      214666 non-null  int64
#  1   Year         214666 non-null  int64
#  2   Month        214666 non-null  int64
#  3   Day          214666 non-null  int64
#  4   Country      214666 non-null  object
#  5   State        214666 non-null  object
#  6   Region       214666 non-null  object
#  7   City         214666 non-null  object
#  8   latitude     209940 non-null  float64
#  9   longitude    209939 non-null  float64
#  10  AttackType   214666 non-null  object
#  11  Killed       201715 non-null  float64
#  12  Wounded      193961 non-null  float64
#  13  Target       214666 non-null  object
#  14  Summary      214666 non-null  object
#  15  Group        214666 non-null  object
#  16  Target_type  214666 non-null  object
#  17  Weapon_type  214666 non-null  object
# ...

# %%
#checking if we have any null values in our dataset and filling it with appropriate values.
df.isnull().sum()
# Out:
# EventId            0
# Year               0
# Month              0
# Day                0
# Country            0
# State              0
# Region             0
# City               0
# latitude        4726
# longitude       4727
# AttackType         0
# Killed         12951
# Wounded        20705
# Target             0
# Summary            0
# Group              0
# Target_type        0
# Weapon_type        0
# Motive             0
# Nationality        0
# Success            0
# dtype: int64

# %%
# filling the null for killed and wounded with median value of the column
df.Wounded=np.round(df.Wounded.fillna(df.Wounded.median())).astype('float64') 
df.Killed=np.round(df.Killed.fillna(df.Killed.median())).astype('float64') 

df.EventId=np.round(df.EventId.fillna(df.EventId.median())).astype('int64') 
df.Year=np.round(df.Year.fillna(df.Year.median())).astype('int64') 
df.Month=np.round(df.Month.fillna(df.Month.median())).astype('int64') 
df.Day=np.round(df.Day.fillna(df.Day.median())).astype('int64') 

#creating a new column casualities and casuality_class --> which is of type binary i.e. 0 and 1
df['Casualities'] = df['Killed']+ df['Wounded']
df['Casuality_class'] = df.Casualities.apply(lambda x: 0 if x == 0 else 1)

df["latitude"] = df["latitude"].fillna(0.0)
df["longitude"] = df["longitude"].fillna(0.0)

df["Success"] = df["Success"].fillna(0)
df.head(5)
# Out:
#         EventId  Year  Month  Day             Country     State  \
# 0  197000000001  1970      7    2  Dominican Republic  National
# 1  197000000002  1970      0    0              Mexico   Federal
# 2  197001000001  1970      1    0         Philippines    Tarlac
# 3  197001000002  1970      1    0              Greece    Attica
# 4  197001000003  1970      1    0               Japan   Fukouka
#
#                         Region           City   latitude   longitude  ...  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164  ...
# 1                North America    Mexico city  19.371887  -99.086624  ...
# 2               Southeast Asia        Unknown  15.478598  120.599741  ...
# 3               Western Europe         Athens  37.997490   23.762728  ...
# 4                    East Asia        Fukouka  33.580412  130.396361  ...
#
#                     Target  Summary                               Group  \
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Percentage of Terror Attacks in different Countries

# %%
plt.figure(figsize=(9,9))
df['Country'].value_counts()[:15].plot(kind='pie',autopct='%1.1f%%')
plt.title('Number of attacks based on countries', size=20)
plt.show()

# %% [markdown]
# ### Casualities over the year

# %%
plt.subplots(figsize=(15,6))
cas = df.groupby('Year').Casualities.sum().to_frame().reset_index()
cas.columns = ['Year','Casualities']
sns.barplot(x = cas.Year, y =cas.Casualities, data=df, palette="rocket_r",ci = None)
plt.xlabel("Year", size=15)
plt.ylabel("Casualities", size=15)
plt.xticks(rotation=90)
plt.title('Casualities Over The Year',size=20)
# Out:
# Text(0.5, 1.0, 'Casualities Over The Year')

# %%
plt.subplots(figsize=(12,8))
cnt_cas = df.groupby('Country').Casualities.sum().to_frame().reset_index().sort_values('Casualities', ascending=False)[:10]
sns.barplot(x=cnt_cas.Country, y=cnt_cas.Casualities, palette= 'inferno')
plt.xticks(rotation=30)
plt.xlabel("Country", size=15)
plt.ylabel("Casualities", size=15)
plt.title('Total Casualities in Each Country', size=20)
plt.show()

# %% [markdown]
# ### Top 5 Regions with terrorist attacks

# %%
plt.subplots(figsize=(12,8))
sns.countplot('Region', data=df,palette='viridis',order=df['Region'].value_counts().index)
plt.title('Regions affected by Terrorist activities', size=20)
plt.xlabel('Regions', size=15)
plt.ylabel('Count', size=15)
plt.xticks(rotation= 90)
plt.show()
# Out:
# C:\Users\Tanish\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df1 = df.groupby(['Region', 'Year']).size().reset_index().pivot(columns='Region', index='Year', values=0)
df1.plot(kind = 'bar', stacked = True, figsize = (50,20), colormap = 'viridis')
plt.legend(loc=2, prop = {'size':30})
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
plt.title("Regions attacked across the years", fontsize = 47)
plt.show()

# %% [markdown]
# <font color=155E64>South Asia, Middle East and North Africa are the most affected regions by terrorist activities</font>

# %% [markdown]
# ### Casuality in various Regions due to Terrorist Attacks

# %%
count = df['Region'].value_counts()[:15].to_frame()
count.columns=['Attacks']
df1=df.groupby('Region')['Casualities'].sum().to_frame()
count.merge(df1,left_index=True,right_index=True,how='left').plot.bar(width=0.9)
fig=plt.gcf()
fig.set_size_inches(18,10)
plt.title('Casualities due to Terrorist Attacks', size=20)
plt.show()

# %%
countryName =  input('Type the country of which you want to perform analysis : ')
# Out:
# Type the country of which you want to perform analysis : Germany

# %%
connection = sqlite3.connect('global_terrorism.db')
cursor = connection.cursor()
# SQL query to retrieve all data 
sql_statement = "SELECT * FROM Global_Terrorism where country_txt='" + countryName + "'"
# print(sql_statement)

df_new = pd.read_sql_query(sql_statement, connection)
df_new
    
connection.close()

df_new = df_new.iloc[1: , :]

# restting the index after deleting the 1st row.
df_new = df_new.reset_index(drop=True)

df_new.rename(columns={'eventid':'EventId','iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State',
                   'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                   'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                   'weaptype1_txt':'Weapon_type','motive':'Motive','city':'City', 'natlty1_txt':'Nationality',
                   'success':'Success'},inplace=True)

df_new=df_new[['EventId','Year','Month','Day','Country','State','Region','City','latitude','longitude','AttackType',
             'Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive','Nationality','Success']]


cols = ["EventId","Year","Month","Day","Success"]
df_new[cols] = df_new[cols].apply(pd.to_numeric, errors='coerce', axis=1)
cols1 = ["latitude","longitude","Killed","Wounded"]
df_new[cols1] = df_new[cols1].apply(pd.to_numeric, errors='coerce', axis=1)
df_new.isnull().sum()
df_new.Wounded=np.round(df_new.Wounded.fillna(df_new.Wounded.median())).astype('float64') 
df_new.Killed=np.round(df_new.Killed.fillna(df_new.Killed.median())).astype('float64') 
df_new.EventId=np.round(df_new.EventId.fillna(df_new.EventId.median())).astype('int64') 
df_new.Year=np.round(df_new.Year.fillna(df_new.Year.median())).astype('int64') 
df.Month=np.round(df_new.Month.fillna(df_new.Month.median())).astype('int64') 
df_new.Day=np.round(df_new.Day.fillna(df_new.Day.median())).astype('int64') 
df_new['Casualities'] = df_new['Killed']+ df_new['Wounded']
df_new['Casuality_class'] = df_new.Casualities.apply(lambda x: 0 if x == 0 else 1)
df_new["latitude"] = df_new["latitude"].fillna(0.0)
df_new["longitude"] = df_new["longitude"].fillna(0.0)
df_new["Success"] = df_new["Success"].fillna(0)

# %%
df_new.head(5)
# Out:
#         EventId  Year  Month  Day  Country                   State  \
# 0  199101140001  1991      1   14  Germany                  Berlin
# 1  199101160005  1991      1   16  Germany  North Rhine-Westphalia
# 2  199101180010  1991      1   18  Germany                  Berlin
# 3  199101220015  1991      1   22  Germany                 Bavaria
# 4  199101310003  1991      1   31  Germany                   Hesse
#
#            Region       City   latitude  longitude  ...  \
# 0  Western Europe     Berlin  52.501530  13.401851  ...
# 1  Western Europe       Bonn  50.732674   7.096299  ...
# 2  Western Europe     Berlin  52.501530  13.401851  ...
# 3  Western Europe   Nurnberg  49.450520  11.080480  ...
# 4  Western Europe  Frankfurt  50.117970   8.644191  ...
#
#                                    Target  Summary                Group  \
# 0          Monument called Victory Column           Revolutionary Cells
# 1                                   Store                       Unknown
# ...

# %% [markdown]
# ###  Terrorist Activities over the years

# %%
plt.subplots(figsize=(15,8))
ax = sns.countplot('Year', data=df_new)
plt.xlabel("Year", size=15)
plt.ylabel("Total Number of Attacks", size=15)
plt.xticks(rotation=90)
plt.title('Terrorist Activities Over The Year For ' + countryName ,size=20)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10),textcoords = 'offset points',  rotation=90)


plt.show()
# Out:
# C:\Users\Tanish\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Casualities due to Terrorist Attacks

# %%
plt.subplots(figsize=(15,6))
cas = df_new.groupby('Year').Casualities.sum().to_frame().reset_index()
cas.columns = ['Year','Casualities']
sns.barplot(x = cas.Year, y =cas.Casualities, data=df_new, palette="rocket_r",ci = None)
plt.xlabel("Year", size=15)
plt.ylabel("Casualities", size=15)
plt.xticks(rotation=90)
plt.title('Casualities Over The Year in ' + countryName ,size=20)
# Out:
# Text(0.5, 1.0, 'Casualities Over The Year in Germany')

# %% [markdown]
# ### Methods used for attack

# %%
plt.subplots(figsize=(15,6))
sns.barplot(x=df_new['AttackType'].value_counts().index, y=df_new['AttackType'].value_counts().values,palette='mako')
plt.title('Attacking methods used by terrorists in ' + countryName, size=20)
plt.xlabel('Attack Types', size=15)
plt.ylabel('Count', size=15)
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# ### Major Targets for Attacks

# %%
plt.subplots(figsize=(15,6))
sns.barplot(x=df_new['Target_type'].value_counts()[:15].index, y=df_new['Target_type'].value_counts()[:15].values,palette='inferno')
plt.title('Favourite target for attacks in ' + countryName, size=20)
plt.xlabel('Target for attacks', size=15)
plt.ylabel('Count', size=15)
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# ### Top Terrorist Group

# %%
Name = df_new[df_new['Group'] == 'Unknown'].index
df_new.drop(Name , inplace=True)
plt.subplots(figsize=(15,6))
sns.barplot(x=df_new['Group'].value_counts().index[:15], y=df_new['Group'].value_counts().values[:15])
plt.xlabel("Terrorist Group", size=15)
plt.ylabel("Count of Attacks", size=15)
plt.xticks(rotation=90)
plt.title('Attacks by Terrorist Groups in ' + countryName,size=20)
# Out:
# Text(0.5, 1.0, 'Attacks by Terrorist Groups in Germany')

# %% [markdown]
# ### Weapons used across the years

# %%
df2 = df_new.groupby(['Weapon_type', 'Year']).size().reset_index().pivot(columns='Weapon_type', index='Year', values=0)
df2.plot(kind = 'bar', stacked = True, figsize = (15,7), colormap = 'Paired')
plt.legend(loc=2, prop = {'size':12})
plt.xlabel("Year", size=15)
plt.title("Weapons used across the years in " + countryName, size=20)
plt.show()

# %% [markdown]
# ### No of people killed by specific weapon

# %%
df3 = df_new[['Weapon_type','Killed']].groupby(by = 'Weapon_type').sum().sort_values('Killed', ascending=False)
plt.figure(figsize = (12,8))
plt.bar(x = df3.index, height = df3['Killed'], color = sns.color_palette('magma'))
plt.xticks(fontsize = 16, rotation = 90)
plt.xlabel('Weapons', size=15)
plt.ylabel("People Killed", size=15)
plt.title("No of people killed by specific weapons in " + countryName, size=20)
plt.show()

# %%
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster, Fullscreen, MiniMap, HeatMap, HeatMapWithTime
filterYear = df['Year'] == 2021
year_list = []
for year in df['Year'].sort_values().unique():
    data = df.query('Year == @year')
    data = data.groupby(by=['latitude', 'longitude'], 
                        as_index=False).count().sort_values(by='EventId', ascending=False).iloc[:, :3]
    year_list.append(data.values.tolist())

m = folium.Map(
    location=[0, 0], 
    zoom_start=2.0, 
    
)

HeatMapWithTime(
    name='Terrorism Heatmap',
    data=year_list,
    radius=9,
    index=list(df['Year'].sort_values().unique())
).add_to(m)
m.save('terrorism_density_year.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ##  Heatmap to graphically represent the correlation of data

# %%
df.corr()
# Out:
#                   EventId      Year     Month       Day  latitude  longitude  \
# EventId          1.000000  0.999996  0.009653  0.018857  0.162536   0.521937
# Year             0.999996  1.000000       NaN  0.018774  0.162575   0.521917
# Month            0.009653       NaN  1.000000 -0.124829  0.065924  -0.002022
# Day              0.018857  0.018774 -0.124829  1.000000  0.004624   0.013523
# latitude         0.162536  0.162575  0.065924  0.004624  1.000000   0.258196
# longitude        0.521937  0.521917 -0.002022  0.013523  0.258196   1.000000
# Killed           0.020418  0.020402 -0.062732 -0.003602 -0.014206   0.004957
# Wounded          0.008890  0.008881  0.053996 -0.001336  0.014843   0.013733
# Success         -0.088066 -0.088063  0.000245 -0.010195 -0.068417  -0.056551
# Casualities      0.012746  0.012734 -0.018851 -0.002047  0.009389   0.013143
# Casuality_class  0.165655  0.165621 -0.025841  0.003729  0.070076   0.172382
#
# ...

# %%
# Graphical representation of the above correlation
#darker the color higher is the magnitude of that phenomenon to occur.
plt.figure(figsize=(16, 6))
sns.heatmap(df.corr(),annot=True,vmin=-1, vmax=1, linewidths=4,cmap=sns.diverging_palette(240, 10, n=10));

# %%
features = df.dtypes[df.dtypes == 'object'].index
for col in features:
    df[col] = df[col].astype('category')
    df[col] = pd.factorize(df[col])[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214666 entries, 0 to 214665
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   EventId          214666 non-null  int64
#  1   Year             214666 non-null  int64
#  2   Month            620 non-null     float64
#  3   Day              214666 non-null  int64
#  4   Country          214666 non-null  int64
#  5   State            214666 non-null  int64
#  6   Region           214666 non-null  int64
#  7   City             214666 non-null  int64
#  8   latitude         214666 non-null  float64
#  9   longitude        214666 non-null  float64
#  10  AttackType       214666 non-null  int64
#  11  Killed           214666 non-null  float64
#  12  Wounded          214666 non-null  float64
#  13  Target           214666 non-null  int64
#  14  Summary          214666 non-null  int64
#  15  Group            214666 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# EventId                 0
# Year                    0
# Month              214046
# Day                     0
# Country                 0
# State                   0
# Region                  0
# City                    0
# latitude                0
# longitude               0
# AttackType              0
# Killed                  0
# Wounded                 0
# Target                  0
# Summary                 0
# Group                   0
# Target_type             0
# Weapon_type             0
# Motive                  0
# Nationality             0
# Success                 0
# Casualities             0
# Casuality_class         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

Features = ['Year','Day','Country','State','Region','City','latitude','longitude','AttackType',
        'Killed','Wounded','Group','Target_type','Weapon_type','Success']

X = df[Features]
Y = df['Casualities']

Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.25,random_state = 43)

print(Xtrain.shape)
print(Xtest.shape)
# Out:
# (160999, 15)
# (53667, 15)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
# Build a forest and compute the feature importances
forest = ExtraTreesClassifier(n_estimators=20,
                              random_state=0)

forest.fit(X, Y)
importances = forest.feature_importances_
print(forest.feature_importances_)
# Out:
# [0.06635189 0.07071841 0.02334187 0.04131378 0.01873088 0.0547706
#  0.05785446 0.06005985 0.06348392 0.20493537 0.20090567 0.03021871
#  0.04991787 0.0374412  0.01995552]

# %%
plt.figure()
plt.title("Feature importances")
feat_importances = pd.Series(forest.feature_importances_, index=X.columns)
feat_importances.nlargest(16).plot(kind='bar')
plt.show()

# %%
feature_final = ['longitude', 'Target_type', 'latitude', 'AttackType', 'Success', 
                'Country', 'Weapon_type', 'Region','Killed','Wounded']
X = df[feature_final]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25)

# %%
model = RandomForestClassifier(n_estimators=20)

model.fit(Xtrain, Ytrain)

Ypred = model.predict(Xtest)

np.mean(Ypred == Ytest)
# Out:
# 0.8677399519257645
